# %% [markdown]
# # BackOffice Security Fixing
# * 74.5 days’ turnaround time (Avg) of BackOffice Security issues.
# * BKOF-10387 is still open with longest turnaround time (99 days).
# * 4 or 5 Jars updated in BKOF-10387,  it's risky to release during AEP/OEP.  BO team will fix it during AEP and release it on 1/3/2020 or 1/10/2020.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project = 'Back Office CORE team' AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("Back Office", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="391292a8716240238c18578e4fdfcb62" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_391292a8716240238c18578e4fdfcb62 = echarts.init(
#                     document.getElementById('391292a8716240238c18578e4fdfcb62'), 'white', {renderer: 'canvas'});
#                 var option_391292a8716240238c18578e4fdfcb62 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Medicare Security Fixing
# * 11 days’ idle time (Avg) of Medicare to start a security issue.
# * 28 days’ turnaround time (Avg) of Medicare Security issues.
# * MEDI-23079 is still open with longest turnaround time (88 days).
# * The turnaround time will keep extending as engineers are focusing on AEP.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project = 'Medicare Scrum Project' AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("Medicare", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dd0c5643134a43358969996f7102ba2e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dd0c5643134a43358969996f7102ba2e = echarts.init(
#                     document.getElementById('dd0c5643134a43358969996f7102ba2e'), 'white', {renderer: 'canvas'});
#                 var option_dd0c5643134a43358969996f7102ba2e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Carrier Integration Security Fixing
# * 98 days’ turnaround time (Avg) of Carrier Integration Security issues.
# * The turnaround time will keep extending as engineers are focusing on AEP/OEP.
# * CEDI-2692 and CEDI-2091 is still open for months.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project = 'Carrier Integration' AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("Carrier Integration", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="561756d7f25a4d7e829ae8887db0510e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_561756d7f25a4d7e829ae8887db0510e = echarts.init(
#                     document.getElementById('561756d7f25a4d7e829ae8887db0510e'), 'white', {renderer: 'canvas'});
#                 var option_561756d7f25a4d7e829ae8887db0510e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # IFP Security Fixing
# * All security issues were closed in IFP.
# * As CEM retired and disabling on some plugin, most issues were closed without engineering work.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project = 'Yoda - IFP Front Office' AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("IFP", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1356497a648f4601ac63173b09ddf146" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1356497a648f4601ac63173b09ddf146 = echarts.init(
#                     document.getElementById('1356497a648f4601ac63173b09ddf146'), 'white', {renderer: 'canvas'});
#                 var option_1356497a648f4601ac63173b09ddf146 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # Platform Security Fixing
# * Platform gets more security issues as it includes 3 teams (Platform, Inventory, FSIS).
# * 17 days’ idle time (Avg) of Platform to start a security issue.
# * 40 days’ turnaround time (Avg) of Platform Security issues.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project in ('Platform Service', 'Product Center', 'Financial Systems and Informational Systems') AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("Platform", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7670e780e6b74ba2af034b7e8c84c491" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7670e780e6b74ba2af034b7e8c84c491 = echarts.init(
#                     document.getElementById('7670e780e6b74ba2af034b7e8c84c491'), 'white', {renderer: 'canvas'});
#                 var option_7670e780e6b74ba2af034b7e8c84c491 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # SMB Security Fixing
# * [x] All security issues were closed with 10.5 days’ idle time.
# * 33.75 days’ turnaround time (Avg) of SMB Security issues.

# %%
import issueTurnaround as it
jql = "issue in linkedIssues('ASEC-201') AND Project = 'VADR - SMB Front Office' AND 'Target Release Date' <= endOfMonth('+1M') AND 'Target Release Date' >= endofMonth('-8M') ORDER BY key ASC"
r = it.prodLineAreaChart("SMB", jql)
r.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9da74160da024d0c88a17d41ef317227" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9da74160da024d0c88a17d41ef317227 = echarts.init(
#                     document.getElementById('9da74160da024d0c88a17d41ef317227'), 'white', {renderer: 'canvas'});
#                 var option_9da74160da024d0c88a17d41ef317227 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#Execute the line below to play this book as PPT using Jupyter built-in function
#!jupyter nbconvert jupyterTest.ipynb --to slides --post serve
